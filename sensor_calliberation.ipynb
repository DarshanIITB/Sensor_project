# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sensor_out = np.array([535, 185, 125])
phone_out = np.array([141, 59, 30])

# %%
sensor_out -= 60
phone_out -= 2
dist = np.array([10, 20, 30])

# %%
plt.plot(phone_out, sensor_out)

# %%
p= [0,30,59,141]
s = [0,125,185,535]
plt.plot(s,p)

# %%
lux = np.array([83, 85, 90, 93, 98, 105, 112, 120, 124, 130])
lux -= 40
lux
# Out:
# array([43, 45, 50, 53, 58, 65, 72, 80, 84, 90])

# %%
dist = np.linspace(30, 21, 10)

# %%
dist
# Out:
# array([30., 29., 28., 27., 26., 25., 24., 23., 22., 21.])

# %%
plt.plot(dist, lux)
plt.plot(dist ,b0/dist**2 + b1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16440\1893645105.py in <module>
#       1 plt.plot(dist, lux)
# ----> 2 plt.plot(dist ,b0/dist**2 + b1)
#
# NameError: name 'b0' is not defined

# %%
obrs = 1/dist**2

# %%
plt.plot(obrs,lux)

# %%
b0,b1=np.polyfit(obrs,lux,1)

# %%
#plt.plot(obrs,lux,'c--')
#plt.plot(obrs,b0*obrs + b1 )

# %% [markdown]
# ![download.png](attachment:download.png)

# %%
lux_phone = np.array([2.5, 31, 46, 55, 63, 70, 81, 86, 99, 129, 185])
lux_sensor = np.array([36, 115, 158, 178, 253, 240, 325, 304, 345, 470, 725])

# %%
plt.plot(lux_sensor, lux_phone,'o')
plt.plot(lux_sensor, lux_phone)
plt.plot(lux_sensor, cal_b1*lux_sensor + cal_b0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16440\3808974657.py in <module>
#       1 plt.plot(lux_sensor, lux_phone,'o')
#       2 plt.plot(lux_sensor, lux_phone)
# ----> 3 plt.plot(lux_sensor, cal_b1*lux_sensor + cal_b0)
#
# NameError: name 'cal_b1' is not defined

# %%
cal_b1, cal_b0 = np.polyfit(lux_sensor, lux_phone, 1)

# %%
cal_b1
# Out:
# 0.2598361671966552

# %%
cal_b0
# Out:
# 2.6614463179757184
